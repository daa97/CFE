# %%
import numpy as np
from fluids import H2
import matplotlib.pyplot as plt

# %%
lin = []
for i in range(5000):
    lin.append(H2(T=i+500.5,P=10e6, linear=True))

# %%
cub = []
for i in range(300):
    cub.append(H2(T=i+500.5,P=985e3))

# %%
#a = [lin[i].rho - cub[i].rho for i in range(len(lin))]
plt.plot([s.vol for s in lin], label="linear")
#plt.plot([s.rho for s in cub], label="cubic")
plt.legend()
plt.show()
