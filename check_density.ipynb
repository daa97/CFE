# %%
import numpy as np
import matplotlib.pyplot as plt

r1 = np.load("Better/r_baseline.npy")

d1 = np.load("Better/d_baseline.npy")

r2 = np.load("Better/r_baseline2.npy")

d2 = np.load("Better/d_baseline2.npy")

r3 = np.load("Better/r_baseline3.npy")

d3 = np.load("Better/d_baseline3.npy")


plt.plot(r1,d1)
plt.plot(r2,d2)
plt.plot(r3,d3)
plt.show()
